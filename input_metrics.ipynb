# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("cleaned_climbharder_data.csv")

x_col = "project_v_grade"
y_col = "max_hang_opencrimp_18mm_10s_kg"

plot_df = df[[x_col, y_col]].dropna()

plot_df.plot(
    kind="scatter",
    x=x_col,
    y=y_col,
    figsize=(8, 5),
    alpha=0.7,
)

plt.title("Project Grade vs Max Hang Open Crimp")
plt.xlabel("Project Grade")
plt.ylabel("Max Hang Open Crimp 18mm 10s (kg)")
plt.show()

df.groupby("project_v_grade")["max_hang_opencrimp_18mm_10s_kg"].mean()
# Out:
# project_v_grade
# 0.0           NaN
# 1.0     48.000000
# 2.0      2.500000
# 3.0     12.631579
# 4.0     16.911111
# 5.0     30.311282
# 6.0     28.698718
# 7.0     42.339130
# 8.0     35.082353
# 9.0     44.250000
# 10.0    68.750000
# 11.0    66.000000
# Name: max_hang_opencrimp_18mm_10s_kg, dtype: float64
